# %%
import ipywidgets as w
class View:
    def __init__(self):
        self.slider_giacenza = w.IntSlider(min=1,max=12)
        self.f_1 = w.IntSlider(min=1,max=12)
        self.f_2 = w.IntSlider(min=1,max=12)
        self.f_3 = w.IntSlider(min=1,max=12)
        self.f_4 = w.IntSlider(min=1,max=12)
    
    def create_page(self):
        page = w.VBox([self.dashboard()])
        return page
        
    def dashboard(self):
        c1 = w.HBox([self.f_1,self.f_2])
        c2 = w.HBox([self.f_3,self.f_4])
        return w.HBox([c1,c2])
        
    def description():
        return
    
    def days_slider():
        return
    
    def output():
        return

# %%
v = View()
print(v)
p=v.create_page()
p
